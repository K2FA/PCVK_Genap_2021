# %% [markdown]
# <a href="https://colab.research.google.com/github/K2FA/PCVK_Genap_2023/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/02/kucing.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/02/kucing.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK/02/kucing.jpeg')

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 plt dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices=np.array([[100,300],
                   [200,200],
                   [400,300],
                   [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))#fungsi reshape adalah mengubah bentuk array tanpa mengubah data
pts#dimana pada kasus ini data data akan dibentuk menjadi per kolom menambahkan kurung siku
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#Tugas 2
img6 = cv.imread('/content/drive/MyDrive/PCVK/02/kucing.jpeg')
img7 = cv.cvtColor(img6,cv.COLOR_BGR2RGB)
R,G,B = cv.split(img7)

zeros = np.zeros(img7.shape[:2], dtype="uint8")
rb = cv.merge([R,zeros,B])
plt.imshow(rb)

# %%
gb = cv.merge([zeros,G,B])
plt.imshow(gb)

# %%
#Tugas 3
img8 = img7
crop = img8[20:115, 25:120]
plt.imshow(crop)

# %%
red = cv.merge([R,zeros,zeros])
y=5
x=0
h=30
w=red.shape[1]
crop = red[y:h, x:w]
plt.imshow(crop)

# %%
from random import randrange
img9 = img7
tinggi = img9.shape[0]                            
lebar = img9.shape[1]  
for x in range(5):
  cv.rectangle(img9, (randrange(lebar),randrange(tinggi)), (randrange(lebar),randrange(tinggi)), (randrange(255),randrange(255),randrange(255)), 5)
plt.imshow(img9)

# %%
img10 = cv.imread('/content/drive/MyDrive/PCVK/02/kucing.jpeg')
img11 =cv.flip( cv.cvtColor(img10,cv.COLOR_BGR2RGB),0)

plt.imshow(img11)

# %%
img12 = cv.imread('/content/drive/MyDrive/PCVK/02/me.jpg')
img13 = cv.cvtColor(img12,cv.COLOR_BGR2RGB)
cv.circle(img13,center=(375,200),radius=200, color=(255,0,0),thickness=5)
cv.rectangle(img13, (600,0), (150,350), color=(0,255,0), thickness=5)
plt.imshow(img13)

# %%
img14 = img12
img15 = cv.cvtColor(img14,cv.COLOR_BGR2RGB)
cv.rectangle(img15,pt1=(150,850), pt2=(15,950), color=(0,0,255), thickness=5)

plt.imshow(img15)

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(img15,text='Khalid',org=(350,950),fontFace=font,fontScale=4,color=(255,0,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(img15)
