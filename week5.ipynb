# %% [markdown]
# <a href="https://colab.research.google.com/github/K2FA/PCVK_Genap_2023/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %%
img_female = cv.imread('/content/drive/MyDrive/PCVK/05/female.tiff')
female_img = cv.cvtColor(img_female, cv.COLOR_BGR2RGB)

# %%
print(' Gamma Correction pada citra ') 
print('----------------------------------') 
try: 
 gamma = int(input('Masukkan nilai Gamma: ')) 
except ValueError: 
 print('Error, not a number') 

female_rgb = cv.cvtColor(female_img, cv.COLOR_BGR2RGB)

gamma_image = np.zeros(female_rgb.shape, female_rgb.dtype)
for y in range(female_rgb.shape[0]):
  for x in range(female_rgb.shape[1]):
    for c in range(female_rgb.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow(female_rgb[y,x,c]/ 255, (1/gamma)), 0 , 255)

final_frame = cv.hconcat((female_rgb, gamma_image))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F44314E7AF0>

# %%
original = cv.imread('/content/drive/MyDrive/PCVK/05/female.tiff', cv.IMREAD_GRAYSCALE) 
depth_image = np.zeros(original.shape, original.dtype) 

bit_depth=2
level = 255 / (pow(2,bit_depth)-1)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    depth_image[y,x] = np.clip(round(original[y,x]/ level) * level, 0 , 255)

final_frame = cv.hconcat((original, depth_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=L size=512x256 at 0x7F4431550AC0>

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/05/galaxy.jpg')
cv_img = [] 
for img in glob.glob('/content/drive/MyDrive/PCVK/05/noises/*.jpg'): 
  n= cv.imread(img) 
  cv_img.append(n) 

dst = cv_img[0]
noise_number = 4 

for i in range(noise_number):
    if i == 0 :
      pass
    else:
      alpha = 1.0 / (i + 1)
      beta = 1.0 - alpha
      dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original-compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20* log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)
mse = np.mean((original - compressed) ** 2)

print('Nilai MSE adalah', mse)
print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai MSE adalah 114.59887012768817
# Nilai PSNR adalah  27.539000250840893 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F44314E7100>

# %%
dst = cv_img[0]
noise_number = 29 

for i in range(noise_number):
    if i == 0 :
      pass
    else:
      alpha = 1.0 / (i + 1)
      beta = 1.0 - alpha
      dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original-compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20* log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)
mse = np.mean((original - compressed) ** 2)

print('Nilai MSE adalah', mse)
print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai MSE adalah 114.87845262096774
# Nilai PSNR adalah  27.528417837494644 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F44313B9340>

# %%
dst = cv_img[0]
noise_number = 59 

for i in range(noise_number):
    if i == 0 :
      pass
    else:
      alpha = 1.0 / (i + 1)
      beta = 1.0 - alpha
      dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original-compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20* log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)
mse = np.mean((original - compressed) ** 2)

print('Nilai MSE adalah', mse)
print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai MSE adalah 115.88238407258065
# Nilai PSNR adalah  27.490629394128558 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F44310903D0>

# %%
dst = cv_img[0]
noise_number = 79

for i in range(noise_number):
    if i == 0 :
      pass
    else:
      alpha = 1.0 / (i + 1)
      beta = 1.0 - alpha
      dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original-compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20* log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)
mse = np.mean((original - compressed) ** 2)

print('Nilai MSE adalah', mse)
print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai MSE adalah 115.59834089381721
# Nilai PSNR adalah  27.501287598788217 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F44315329D0>

# %%
dst = cv_img[0]
noise_number = 99

for i in range(noise_number):
    if i == 0 :
      pass
    else:
      alpha = 1.0 / (i + 1)
      beta = 1.0 - alpha
      dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original-compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20* log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)
mse = np.mean((original - compressed) ** 2)

print('Nilai MSE adalah', mse)
print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai MSE adalah 115.57711273521505
# Nilai PSNR adalah  27.502085198362316 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F4431550DC0>

# %%
couple = cv.imread('/content/drive/MyDrive/PCVK/05/couple.tiff')
# couple_img = cv.cvtColor(couple,cv.COLOR_BGR2RGB)
t=couple.shape[0]
l=couple.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(couple.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 30, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 30, (255,255,255), -1)

result = couple & mask & mask1 





circle_frame = cv.hconcat((couple, result))
cv2_imshow(circle_frame)
# Out:
# t =  256 l =  256
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F44314EB3A0>

# %%
# NO 5
t=couple.shape[0]
l=couple.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(couple.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = couple | mask & mask1 

circle_frame = cv.hconcat((couple, result))
cv2_imshow(circle_frame)
# Out:
# t =  256 l =  256
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F4431364C70>

# %%
t=couple.shape[0]
l=couple.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(couple.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~couple & ~mask

circle_frame = cv.hconcat((couple, result))
cv2_imshow(circle_frame)
# Out:
# t =  256 l =  256
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F443136EAF0>

# %%
t=couple.shape[0]
l=couple.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(couple.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~couple & mask

circle_frame = cv.hconcat((couple, result))
cv2_imshow(circle_frame)
# Out:
# t =  256 l =  256
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F443136DFD0>

# %%
t=couple.shape[0]
l=couple.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(couple.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = couple ^ mask

circle_frame = cv.hconcat((couple, result))
cv2_imshow(circle_frame)
# Out:
# t =  256 l =  256
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F4431090730>
